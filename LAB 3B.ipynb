# %% [markdown]
# # Create a summary of a news article

# %%
import numpy as np
import pandas as pd
import pip
pip.main(['install', 'requests'])
pip.main(["install","newspaper3k"])
import newspaper
from newspaper import Article
from  textblob import TextBlob
# Out:
# Requirement already satisfied: requests in c:\users\anu\anaconda3\lib\site-packages
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\anu\anaconda3\lib\site-packages (from requests)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\anu\anaconda3\lib\site-packages (from requests)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\anu\anaconda3\lib\site-packages (from requests)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anu\anaconda3\lib\site-packages (from requests)
# Requirement already satisfied: newspaper3k in c:\users\anu\anaconda3\lib\site-packages
# Requirement already satisfied: cssselect>=0.9.2 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: tldextract>=2.0.1 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: lxml>=3.6.0 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: nltk>=3.2.1 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: requests>=2.10.0 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: Pillow>=3.3.0 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: feedfinder2>=0.0.4 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: jieba3k>=0.35.1 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: feedparser>=5.2.1 in c:\users\anu\anaconda3\lib\site-packages (from newspaper3k)
# Requirement already satisfied: setuptools in c:\users\anu\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k)
# Requirement already satisfied: requests-file>=1.4 in c:\users\anu\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k)
# Requirement already satisfied: idna in c:\users\anu\anaconda3\lib\site-packages (from tldextract>=2.0.1->newspaper3k)
# Requirement already satisfied: six in c:\users\anu\anaconda3\lib\site-packages (from nltk>=3.2.1->newspaper3k)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\anu\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\anu\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anu\anaconda3\lib\site-packages (from requests>=2.10.0->newspaper3k)
# Requirement already satisfied: olefile in c:\users\anu\anaconda3\lib\site-packages (from Pillow>=3.3.0->newspaper3k)

# %%
url = 'https://www.bloomberg.com/news/articles/2018-02-22/if-you-believe-quants-nothing-happened-in-markets-this-month'
article = newspaper.Article(url)
article.download()
article.parse()
article.title
article.nlp()
article.keywords
article.summary
blob2 = TextBlob(article.text)
article.summary
# Out:
# 'Momentum stocks have continued to ride high.\nAnd value stocks have continued to get pummeled, even after some analysts predicted a sharp rotation into those shares.\nTake value stocks, which are priced at discounts to things like earnings or assets.\nOne-month realized volatility hit a 17-month high for the pure momentum strategy on Dec. 13, but this month it has hovered near the five-year average.\n“The net under-exposure of active hedge funds to value should increase the upside of a value rotation.”'

# %%
wordlist = pd.DataFrame()
ssList=[]
for t in blob2.sentences:
    ww = []
    for word, tag in t.tags:
        if tag in ('NN', 'NNS', 'NNP', 'NNPS', 'VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ'):
            ww.append(word.lemmatize())
    ss = ' '.join(ww)
    ssList.append(ss.lower())

# %%
wordlist = wordlist.append(ssList, ignore_index=True)    

wordlist
len(blob2.sentences)
wordlist.to_csv('summary.csv')
wordlist
# Out:
#                                                     0
# 0                 ’ playbook factor market go haywire
# 1                     february is guide rule are date
# 2   selloff momentum stock defined gainer year ten...
# 3   factor low-volatility dividend payer provide p...
# 4                                     hasn t happened
# 5   factors have been bout turbulence fear spike t...
# 6                  momentum stock have continued ride
# 7   value stock have continued get pummeled analys...
# 8   performance have caught quants surprise signal...
# 9                    factors behave growth begin slow
# 10  take value stock are priced discount thing ear...
# 11  tend outperform inflation rise according sanfo...
# 12  data hinting price value ha extended losing st...
# 13   ’ stock lose steam bull market researcher reason
# 14                 are saying are cycle expansion i.e
# 15  period growth is decelerating factor tend domi...
# 16  “ remain growth momentum expansion. ” momentum...
# 17  version u.s. momentum reversed loss day is tra...
# 18  fact momentum is calm wa december u.s. stock w...
# 19  realized volatility hit high pure momentum str...
# 20                   investor have remained steadfast
# 21  hedge fund institution maintained reliance gro...
# 22  length rally equity market ha encouraged hedge...
# 23  continued improvement prospect rising inflatio...
# 24  under-exposure hedge fund value increase upsid...
# 25                ’ playbook factor market go haywire
# 26                    february is guide rule are date
# 27  selloff momentum stock defined gainer year ten...
# 28  factor low-volatility dividend payer provide p...
# 29                                    hasn t happened
# 30  factors have been bout turbulence fear spike t...
# 31                 momentum stock have continued ride
# 32  value stock have continued get pummeled analys...
# 33  performance have caught quants surprise signal...
# 34                   factors behave growth begin slow
# 35  take value stock are priced discount thing ear...
# 36  tend outperform inflation rise according sanfo...
# 37  data hinting price value ha extended losing st...
# 38   ’ stock lose steam bull market researcher reason
# 39                 are saying are cycle expansion i.e
# 40  period growth is decelerating factor tend domi...
# 41  “ remain growth momentum expansion. ” momentum...
# 42  version u.s. momentum reversed loss day is tra...
# 43  fact momentum is calm wa december u.s. stock w...
# 44  realized volatility hit high pure momentum str...
# 45                   investor have remained steadfast
# 46  hedge fund institution maintained reliance gro...
# 47  length rally equity market ha encouraged hedge...
# 48  continued improvement prospect rising inflatio...
# 49  under-exposure hedge fund value increase upsid...

# %%
tweettext=df['text']
user= json_normalize(df['user'])
tweettext
name= user['screen_name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b1ad46a04f9d> in <module>()
# ----> 1 tweettext=df['text']
#       2 user= json_normalize(df['user'])
#       3 tweettext
#       4 name= user['screen_name']
#
# NameError: name 'df' is not defined
